# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('Kunal.jpg',0)
plt.imshow(img,'gray')
print(img)
# Out:
# [[113 113 113 ... 165 168 168]
#  [108 108 111 ... 161 169 173]
#  [106 104 104 ... 164 169 169]
#  ...
#  [200 199 199 ... 138 142 144]
#  [204 202 200 ... 140 143 144]
#  [199 200 202 ... 139 141 140]]

# %%
img.shape
# Out:
# (720, 1280)

# %%
def zero_or_one(img, center, i, j): 
      
    val1=0
      
    try:  
        if img[i][j] >= center: 
            val1 = 1
              
    except:  
        pass
      
    return val1

# %%
lbp_img = np.zeros((img.shape[0],img.shape[1]), np.uint8)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        center=img[i][j]
        val=[]
        val.append(zero_or_one(img, center, i-1, j-1)) 
        val.append(zero_or_one(img, center, i-1, j))  
        val.append(zero_or_one(img, center, i-1, j+1))  
        val.append(zero_or_one(img, center, i, j+1))  
        val.append(zero_or_one(img, center, i+1, j+1))  
        val.append(zero_or_one(img, center, i+1, j))  
        val.append(zero_or_one(img, center, i+1,j-1))  
        val.append(zero_or_one(img, center, i, j-1))
          
            

            
        v=0
        for k in range(len(val)):
            v += val[k] * pow(2,(7-k))
        
        
        lbp_img[i][j]=v

# %%
print(lbp_img)
plt.imshow(lbp_img,"gray")
#plt.show()
# Out:
# [[243 241 249 ...  25  28   7]
#  [243 241 240 ... 254  28   0]
#  [227 241 249 ...  62 118 195]
#  ...
#  [ 12  31  63 ... 124  60   4]
#  [  0   9  63 ...  56  48  64]
#  [112 240 144 ... 112  96 193]]
